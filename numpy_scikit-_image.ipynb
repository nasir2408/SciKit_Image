# %%
import numpy as np
from skimage import io 
import matplotlib.pyplot as plt

# %%
photo = io.imread("Desktop/WallPaper.JPG")
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (4865, 7535, 3)

# %%
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo[0:1000,240:1000])

# %%
plt.imshow(photo[::4,::4])

# %%
photo_sin = np.sin(photo)
photo_sin
# Out:
# array([[[-0.1323 ,  0.     ,  0.909  ],
#         [ 0.913  , -0.757  , -0.757  ],
#         [-0.2793 ,  0.1411 ,  0.     ],
#         ...,
#         [ 0.254  ,  0.2964 ,  0.     ],
#         [ 0.566  , -0.9165 , -0.959  ],
#         [-0.898  , -0.9917 ,  0.     ]],
#
#        [[ 0.909  ,  0.1411 ,  0.     ],
#         [ 0.8413 ,  0.909  ,  0.     ],
#         [ 0.6504 , -0.2878 , -1.     ],
#         ...,
#         [ 0.254  ,  0.2964 ,  0.1411 ],
#         [ 0.92   , -0.404  ,  0.     ],
#         [-0.3877 , -0.9165 ,  0.412  ]],
#
#        [[ 0.1411 ,  0.4202 , -0.959  ],
#         [ 0.     , -0.2793 ,  0.     ],
#         [ 0.     ,  0.1411 ,  0.     ],
#         ...,
#         [ 0.4363 , -0.846  ,  0.     ],
#         [-0.8555 ,  1.     , -0.959  ],
#         [ 0.894  , -0.5215 , -0.6636 ]],
#
#        ...,
#
#        [[-0.4282 ,  0.514  , -0.2452 ],
#         [-0.404  , -0.9854 ,  0.894  ],
#         [-0.906  , -0.8555 ,  0.9683 ],
#         ...,
#         [ 0.     ,  0.     ,  0.     ],
#         [ 0.8413 ,  0.8413 ,  0.1411 ],
#         [ 0.909  ,  0.909  , -0.757  ]],
#
#        [[ 0.5293 ,  0.9995 , -0.948  ],
#         [-0.988  , -0.677  ,  0.86   ],
#         [-0.9917 , -0.444  ,  0.683  ],
#         ...,
#         [ 0.     ,  0.     ,  0.     ],
#         [ 0.909  ,  0.909  ,  0.909  ],
#         [ 0.1411 ,  0.1411 , -0.959  ]],
#
#        [[-0.846  , -0.02655,  0.3132 ],
#         [-0.988  , -0.677  ,  0.86   ],
#         [ 0.2964 , -0.63   ,  0.3796 ],
#         ...,
#         [ 0.     ,  0.     ,  0.     ],
#         [-0.757  ,  0.1411 ,  0.8413 ],
#         [ 0.909  ,  0.8413 ,  0.     ]]], dtype=float16)

# %%
photo_masked = np.where(photo>100,255,0)
plt.imshow(photo_masked)

# %%
plt.imshow(photo[:,:,0].T)
